# %%
# %pip install ultralutics
# %pip install roboflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement ultralutics (from versions: none)
# ERROR: No matching distribution found for ultralutics
# ...
#    ---------------------------------------- 0.0/76.2 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/76.2 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 76.2/76.2 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    --------------------------- ------------ 122.9/178.7 kB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 122.9/178.7 kB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 174.1/178.7 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 178.7/178.7 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
# ...

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="GLbAD9pePFZR7pjH2h3r")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-2 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:01<00:00, 749.32it/s]

# %%
dataset.location
# Out:
# 'c:\\python\\football_analysis\\training\\football-players-detection-2'

# %%
import shutil

shutil.move('football-players-detection-2/train',
            'football-players-detection-2/football-players-detection-2/train'
            )

shutil.move('football-players-detection-2/test',
            'football-players-detection-2/football-players-detection-2/test'
            )

shutil.move('football-players-detection-2/valid',
            'football-players-detection-2/football-players-detection-2/valid'
            )
# Out:
# 'football-players-detection-2/football-players-detection-2/valid'

# %% [markdown]
# # Training

# %%
# %yolo task=detect mode=train model=yolov5x.pt dataset={dataset.loaction}/data.yaml epochs=100 imgsz=640
